# %%
import mysql.connector as conn
import pandas as pd

# %%
myconn = conn.connect(host = 'localhost', user = 'root', passwd = '12345')

# %%
cursor = myconn.cursor()

# %%
query = 'show databases'

cursor.execute(query)

cursor.fetchall()
# Out:
# [('assign',),
#  ('assignment',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
query = 'USE assign'

cursor.execute(query)

# %%
query = 'show tables'

cursor.execute(query)

cursor.fetchall()
# Out:
# [('employees',), ('employees1',), ('people',), ('peoplessss',), ('products',)]

# %%
query = """
SELECT *
FROM employees
"""
data = pd.read_sql_query(query, myconn)

data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\4003693635.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
# Empty DataFrame
# Columns: [employee_id, first_name, last_name, salary, department]
# Index: []

# %%
query = """
INSERT INTO employees1(employee_id, first_name, last_name, salary, department)
VALUES(5, 'ajit', 'vans', 3000, 'HR'),
      (4, 'aditya', 'singh', 5000, 'IT'),
      (3, 'Pooja', 'jain', 9000, 'HR'),
      (2, 'aadi', 'jaya', 9000, 'IT')
"""

cursor.execute(query)

# %%
query = """
SELECT *
FROM employees1
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\285262745.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
# Empty DataFrame
# Columns: [employee_id, first_name, last_name, salary, department]
# Index: []

# %% [markdown]
# Question 4: Extract Records with Salary Within a Range
# Description: Given the 'employees' table with fields:
# - employee_id (integer)
# - first_name (string, max length 50)
# - last_name (string, max length 50)
# - salary (decimal with 2 decimal places)
# - department (string, max length 50)
# Extract records from the 'employees' table where the salary falls within the
# range of 70000 to 80000.

# %%
query = """
SELECT *
FROM employees1
WHERE salary BETWEEN 70000.00 AND 80000.00;
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\2764918701.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
# Empty DataFrame
# Columns: [employee_id, first_name, last_name, salary, department]
# Index: []

# %% [markdown]
# Question 5: Delete Records with Specific Conditions
# Description: Given the 'employees' table with fields:
# - employee_id (integer)
# - first_name (string, max length 50)
# - last_name (string, max length 50)
# - salary (decimal with 2 decimal places)
# - department (string, max length 50)
# Delete records from the 'employees' table where either the first_name is
# 'Pooja' or the salary is less than 75000.

# %%
query = """
DELETE FROM employees1
WHERE first_name = "Pooja"
OR salary < 7500
"""

data = pd.read_sql_query(query, myconn)

data

# %%
query = """
SELECT *
FROM employees1
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\285262745.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#    employee_id first_name last_name  salary department
# 0            2       aadi      jaya  9000.0         IT

# %% [markdown]
# Question 6:
# Description: Given the 'country' table with fields:
# - Code (string, max length 3)
# - Name (string, max length 52)
# - Continent (string, max length 13)
# - Population (integer)
# Select the top 5 countries with the highest population.

# %%
query = 'USE world'

cursor.execute(query)

# %%
query = """
SELECT *
FROM country
ORDER BY Population DESC
LIMIT 5;
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\885498686.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#   Code           Name      Continent                     Region  SurfaceArea  \
# 0  CHN          China           Asia               Eastern Asia    9572900.0
# 1  IND          India           Asia  Southern and Central Asia    3287263.0
# 2  USA  United States  North America              North America    9363520.0
# 3  IDN      Indonesia           Asia             Southeast Asia    1904569.0
# 4  BRA         Brazil  South America              South America    8547403.0
#
#    IndepYear  Population  LifeExpectancy        GNP     GNPOld      LocalName  \
# 0      -1523  1277558000            71.4   982268.0   917719.0       Zhongquo
# ...

# %% [markdown]
# Question 7:
# Description: Given the 'city' table with fields:
# - ID (integer)
# - Name (string, max length 35)
# - CountryCode (string, max length 3)
# - District (string, max length 20)
# - Population (integer)
# Select cities where the population is between 500,000 and 1,000,000,
# ordered by population in descending order.

# %%
query = """
SELECT *
FROM city
WHERE Population BETWEEN 500000 AND 1000000
ORDER BY Population DESC
"""

data = pd.read_sql_query(query, myconn)

print(data.shape)

data
# Out:
# (303, 5)
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\1876469653.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#        ID          Name CountryCode              District  Population
# 0    1786         Amman         JOR                 Amman     1000000
# 1    3214     Mogadishu         SOM              Banaadir      997000
# 2    3592     Volgograd         RUS             Volgograd      993400
# 3    1543        Sendai         JPN                Miyagi      989975
# 4    2829      Peshawar         PAK  Nothwest Border Prov      988005
# ..    ...           ...         ...                   ...         ...
# 298  2490          Salé         MAR  Rabat-Salé-Zammour-Z      504420
# 299  1073    Chandigarh         IND            Chandigarh      504094
# ...

# %% [markdown]
# Question 8:
# Description: Given the 'country' table with fields:
# - Code (string, max length 3)
# - Name (string, max length 52)
# - Continent (string, max length 13)
# - Population (integer)
# Select the continent with the highest average population.

# %%
query = """
SELECT Continent, AVG(Population) As avg
FROM country
GROUP BY Continent
ORDER BY DESC avg 
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\4293384959.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#        Continent           avg
# 0           Asia  7.264756e+07
# 1  South America  2.469857e+07
# 2         Europe  1.587119e+07
# 3         Africa  1.352543e+07
# 4  North America  1.305386e+07
# 5        Oceania  1.085755e+06
# 6     Antarctica  0.000000e+00

# %%
query = """
SELECT Continent, AVG(Population) AS avg
FROM country
GROUP BY Continent
ORDER BY avg DESC
"""

data = pd.read_sql_query(query, myconn)

data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\4212019002.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#        Continent           avg
# 0           Asia  7.264756e+07
# 1  South America  2.469857e+07
# 2         Europe  1.587119e+07
# 3         Africa  1.352543e+07
# 4  North America  1.305386e+07
# 5        Oceania  1.085755e+06
# 6     Antarctica  0.000000e+00

# %%
query = """
SELECT *
FROM country
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\3669802541.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %% [markdown]
# Question 9:
# Description: Given the 'country' table with fields:
# - Code (string, max length 3)
# - Name (string, max length 52)
# - Continent (string, max length 13)
# - Population (integer)
# Select the top 3 continents with the highest total population.

# %%
query = """
SELECT Continent, SUM(Population) AS total
FROM country
GROUP BY Continent
ORDER BY total DESC
LIMIT 3
"""

data = pd.read_sql_query(query, myconn)

data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\866875948.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#   Continent         total
# 0      Asia  3.705026e+09
# 1    Africa  7.844750e+08
# 2    Europe  7.300746e+08

# %% [markdown]
# Question 10:
# Description: Given the 'city' table with fields:
# - ID (integer)
# - Name (string, max length 35)
# - CountryCode (string, max length 3)
# - District (string, max length 20)
# - Population (integer)
# Select cities with a population greater than the average population.

# %%
query = """
SELECT *
FROM country
WHERE Population > (SELECT AVG(Population) FROM city)
LIMIT 3
"""

data = pd.read_sql_query(query, myconn)

data
# Out:
# C:\Users\Amogh\AppData\Local\Temp\ipykernel_7452\999521728.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, myconn)
#   Code         Name Continent                     Region  SurfaceArea  \
# 0  AFG  Afghanistan      Asia  Southern and Central Asia     652090.0
# 1  AGO       Angola    Africa             Central Africa    1246700.0
# 2  ALB      Albania    Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0       1919    22720000            45.9  5976.0     NaN
# 1       1975    12878000            38.3  6648.0  7984.0
# 2       1912     3401200            71.6  3205.0  2500.0
#
#                LocalName   GovernmentForm              HeadOfState  Capital  \
# ...
